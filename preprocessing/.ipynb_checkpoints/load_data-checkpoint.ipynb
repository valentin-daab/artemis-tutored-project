# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %% [markdown]
# # Installed Capacity per Production Type

# %%
import pandas as pd

from datetime import timedelta
from entsoe import EntsoePandasClient
from IPython.core.display import HTML

# %%
client = EntsoePandasClient(api_key="24cce779-5703-422f-91b0-b5c9e860e1db")

start = pd.Timestamp('20000101', tz='Europe/Brussels')
end = pd.Timestamp('20200102', tz='Europe/Brussels')

country_code = ['AL', 'AT', 'BE', 'BA', 'BG', 'HR', 'CY', 'CZ', 'DK',
               'EE', 'FI', 'FR', 'DE', 'GR', 'HU', 'IE', 'IT',
               'LV', 'LT', 'LU', 'ME', 'NL', 'MK', 'NO', 'PL',
               'PT', 'RO', 'RS', 'SK', 'SI', 'ES', 'SE', 'CH', 'UA',
               'UK']

#out : GE, XK

# %%
df = pd.DataFrame()


for count, value in enumerate(country_code) :
    temp_df = client.query_installed_generation_capacity(value, start=start,end=end, psr_type=None)
    temp_df.insert(0, 'Country', value)
    df = pd.concat([df, temp_df])
    print(value)
    temp_df = pd.DataFrame()
# Out:
# AL
# AT
# BE
# BA
# BG
# HR
# CY
# CZ
# DK
# EE
# FI
# FR
# DE
# GR
# HU
# IE
# IT
# LV
# LT
# LU
# ME
# NL
# MK
# NO
# PL
# PT
# RO
# RS
# SK
# SI
# ES
# SE
# CH
# UA
# UK

# %% [markdown]
# # Actual generation per production type

# %%
df = pd.DataFrame()

start = pd.Timestamp('20150101', tz='Europe/Brussels')
end = pd.Timestamp('20200101', tz='Europe/Brussels')

country_code = ['AT', 'FR', 'DE', 'UK', 'LU', 'RO']

for count, value in enumerate(country_code) :
    temp_df = client.query_generation(value, start=start,end=end, psr_type=None)
    temp_df.insert(0, 'Country', value)
    df = pd.concat([df, temp_df])
    print(value)
    temp_df = pd.DataFrame()
# Out:
# AT
# FR
# DE
# UK
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       9 temp_df = client.query_generation(value, start=start,end=end, psr_type=None)
#      10 temp_df.insert(0, 'Country', value)
# ---> 11 df = pd.concat([df, temp_df])
#      12 print(value)
#      13 temp_df = pd.DataFrame()
#
# File ~\miniconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\concat.py:381, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     159 """
#     160 Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366 1   3   4
#     367 """
#     368 op = _Concatenator(
#     369     objs,
#     370     axis=axis,
#    (...)
#     378     sort=sort,
#     379 )
# --> 381 return op.get_result()
#
# File ~\miniconda3\lib\site-packages\pandas\core\reshape\concat.py:616, in _Concatenator.get_result(self)
#     612             indexers[ax] = obj_labels.get_indexer(new_labels)
#     614     mgrs_indexers.append((obj._mgr, indexers))
# --> 616 new_data = concatenate_managers(
#     617     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618 )
#     619 if not self.copy:
#     620     new_data._consolidate_inplace()
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\concat.py:233, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     231     fastpath = blk.values.dtype == values.dtype
#     232 else:
# --> 233     values = _concatenate_join_units(join_units, concat_axis, copy=copy)
#     234     fastpath = False
#     236 if fastpath:
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\concat.py:537, in _concatenate_join_units(join_units, concat_axis, copy)
#     533 if concat_axis == 0 and len(join_units) > 1:
#     534     # Concatenating join units along ax0 is handled in _merge_blocks.
#     535     raise AssertionError("Concatenating join units along axis0")
# --> 537 empty_dtype = _get_empty_dtype(join_units)
#     539 has_none_blocks = any(unit.block.dtype.kind == "V" for unit in join_units)
#     540 upcasted_na = _dtype_to_na_value(empty_dtype, has_none_blocks)
#
# File ~\miniconda3\lib\site-packages\pandas\core\internals\concat.py:629, in _get_empty_dtype(join_units)
#     626 if not len(dtypes):
#     627     dtypes = [unit.dtype for unit in join_units if unit.block.dtype.kind != "V"]
# --> 629 dtype = find_common_type(dtypes)
#     630 if has_none_blocks:
#     631     dtype = ensure_dtype_can_hold_na(dtype)
#
# File ~\miniconda3\lib\site-packages\pandas\core\dtypes\cast.py:1607, in find_common_type(types)
#    1590 """
#    1591 Find a common data type among the given dtypes.
#    1592
#    (...)
#    1604
#    1605 """
#    1606 if not types:
# -> 1607     raise ValueError("no types given")
#    1609 first = types[0]
#    1611 # workaround for find_common_type([np.dtype('datetime64[ns]')] * 2)
#    1612 # => object
#
# ValueError: no types given

# %%
df
# Out:
#                           Country           Biomass                     \
#                                   Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00      AT             304.0                0.0
# 2015-01-01 00:15:00+01:00      AT             304.0                0.0
# 2015-01-01 00:30:00+01:00      AT             304.0                0.0
# 2015-01-01 00:45:00+01:00      AT             304.0                0.0
# 2015-01-01 01:00:00+01:00      AT             304.0                0.0
# ...                           ...               ...                ...
# 2019-12-31 20:30:00+00:00      UK            3018.0                NaN
# 2019-12-31 21:00:00+00:00      UK            3018.0                NaN
# 2019-12-31 21:30:00+00:00      UK            3015.0                NaN
# 2019-12-31 22:00:00+00:00      UK            3012.0                NaN
# 2019-12-31 22:30:00+00:00      UK            2830.0                NaN
#
#                                  Fossil Gas                     \
#                           Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00            1029.0                0.0
# 2015-01-01 00:15:00+01:00            1019.0                0.0
# 2015-01-01 00:30:00+01:00            1015.0                0.0
# 2015-01-01 00:45:00+01:00            1014.0                0.0
# 2015-01-01 01:00:00+01:00             926.0                0.0
# ...                                     ...                ...
# 2019-12-31 20:30:00+00:00           12699.0                0.0
# 2019-12-31 21:00:00+00:00           11988.0                0.0
# 2019-12-31 21:30:00+00:00           10583.0                0.0
# 2019-12-31 22:00:00+00:00           10401.0                0.0
# 2019-12-31 22:30:00+00:00            9933.0                0.0
#
#                            Fossil Hard coal                     \
#                           Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00              16.0                0.0
# 2015-01-01 00:15:00+01:00              16.0                0.0
# 2015-01-01 00:30:00+01:00              15.0                0.0
# 2015-01-01 00:45:00+01:00              15.0                0.0
# 2015-01-01 01:00:00+01:00              14.0                0.0
# ...                                     ...                ...
# 2019-12-31 20:30:00+00:00            1578.0                0.0
# 2019-12-31 21:00:00+00:00            1113.0                0.0
# 2019-12-31 21:30:00+00:00            1104.0                0.0
# 2019-12-31 22:00:00+00:00             999.0                0.0
# 2019-12-31 22:30:00+00:00             913.0                0.0
#
#                                  Fossil Oil                     \
#                           Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00               0.0                0.0
# 2015-01-01 00:15:00+01:00               0.0                0.0
# 2015-01-01 00:30:00+01:00               0.0                0.0
# 2015-01-01 00:45:00+01:00               0.0                0.0
# 2015-01-01 01:00:00+01:00               0.0                0.0
# ...                                     ...                ...
# 2019-12-31 20:30:00+00:00               0.0                0.0
# 2019-12-31 21:00:00+00:00               0.0                0.0
# 2019-12-31 21:30:00+00:00               0.0                0.0
# 2019-12-31 22:00:00+00:00               0.0                0.0
# 2019-12-31 22:30:00+00:00               0.0                0.0
#
#                                  Geothermal  ...      Wind Onshore  \
#                           Actual Aggregated  ... Actual Aggregated
# 2015-01-01 00:00:00+01:00               0.0  ...              63.0
# 2015-01-01 00:15:00+01:00               0.0  ...              61.0
# 2015-01-01 00:30:00+01:00               0.0  ...              65.0
# 2015-01-01 00:45:00+01:00               0.0  ...              71.0
# 2015-01-01 01:00:00+01:00               0.0  ...              74.0
# ...                                     ...  ...               ...
# 2019-12-31 20:30:00+00:00               NaN  ...            3351.0
# 2019-12-31 21:00:00+00:00               NaN  ...            3494.0
# 2019-12-31 21:30:00+00:00               NaN  ...            3718.0
# 2019-12-31 22:00:00+00:00               NaN  ...            3890.0
# 2019-12-31 22:30:00+00:00               NaN  ...            3677.0
#
#                                                        Nuclear  \
#                           Actual Consumption Actual Aggregated
# 2015-01-01 00:00:00+01:00                0.0               NaN
# 2015-01-01 00:15:00+01:00                0.0               NaN
# 2015-01-01 00:30:00+01:00                0.0               NaN
# 2015-01-01 00:45:00+01:00                0.0               NaN
# 2015-01-01 01:00:00+01:00                0.0               NaN
# ...                                      ...               ...
# 2019-12-31 20:30:00+00:00              193.0            6961.0
# 2019-12-31 21:00:00+00:00              239.0            6955.0
# 2019-12-31 21:30:00+00:00              280.0            6969.0
# 2019-12-31 22:00:00+00:00              307.0            6962.0
# 2019-12-31 22:30:00+00:00              302.0            6958.0
#
#                           Fossil Brown coal/Lignite                     \
#                                   Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00                       NaN                NaN
# 2015-01-01 00:15:00+01:00                       NaN                NaN
# 2015-01-01 00:30:00+01:00                       NaN                NaN
# 2015-01-01 00:45:00+01:00                       NaN                NaN
# 2015-01-01 01:00:00+01:00                       NaN                NaN
# ...                                             ...                ...
# 2019-12-31 20:30:00+00:00                       NaN                NaN
# 2019-12-31 21:00:00+00:00                       NaN                NaN
# 2019-12-31 21:30:00+00:00                       NaN                NaN
# 2019-12-31 22:00:00+00:00                       NaN                NaN
# 2019-12-31 22:30:00+00:00                       NaN                NaN
#
#                           Fossil Coal-derived gas                     \
#                                 Actual Aggregated Actual Consumption
# 2015-01-01 00:00:00+01:00                     NaN                NaN
# 2015-01-01 00:15:00+01:00                     NaN                NaN
# 2015-01-01 00:30:00+01:00                     NaN                NaN
# 2015-01-01 00:45:00+01:00                     NaN                NaN
# 2015-01-01 01:00:00+01:00                     NaN                NaN
# ...                                           ...                ...
# 2019-12-31 20:30:00+00:00                     NaN                NaN
# 2019-12-31 21:00:00+00:00                     NaN                NaN
# 2019-12-31 21:30:00+00:00                     NaN                NaN
# 2019-12-31 22:00:00+00:00                     NaN                NaN
# 2019-12-31 22:30:00+00:00                     NaN                NaN
#
#                                      Nuclear     Wind Offshore  \
#                           Actual Consumption Actual Aggregated
# 2015-01-01 00:00:00+01:00                NaN               NaN
# 2015-01-01 00:15:00+01:00                NaN               NaN
# 2015-01-01 00:30:00+01:00                NaN               NaN
# 2015-01-01 00:45:00+01:00                NaN               NaN
# 2015-01-01 01:00:00+01:00                NaN               NaN
# ...                                      ...               ...
# 2019-12-31 20:30:00+00:00                NaN            1964.0
# 2019-12-31 21:00:00+00:00                NaN            1770.0
# 2019-12-31 21:30:00+00:00                NaN            1816.0
# 2019-12-31 22:00:00+00:00                NaN            1985.0
# 2019-12-31 22:30:00+00:00                NaN            2178.0
#
#
#                           Actual Consumption
# 2015-01-01 00:00:00+01:00                NaN
# 2015-01-01 00:15:00+01:00                NaN
# 2015-01-01 00:30:00+01:00                NaN
# 2015-01-01 00:45:00+01:00                NaN
# 2015-01-01 01:00:00+01:00                NaN
# ...                                      ...
# 2019-12-31 20:30:00+00:00                NaN
# 2019-12-31 21:00:00+00:00                NaN
# 2019-12-31 21:30:00+00:00                NaN
# 2019-12-31 22:00:00+00:00                NaN
# 2019-12-31 22:30:00+00:00                NaN
#
# [481852 rows x 35 columns]

# %%
df1 = df

# %%
df1 = df1.reset_index(level=0)

# %%
df1
# Out:
#                             index Country           Biomass  \
#                                           Actual Aggregated
# 0       2015-01-01 00:00:00+01:00      AT             304.0
# 1       2015-01-01 00:15:00+01:00      AT             304.0
# 2       2015-01-01 00:30:00+01:00      AT             304.0
# 3       2015-01-01 00:45:00+01:00      AT             304.0
# 4       2015-01-01 01:00:00+01:00      AT             304.0
# ...                           ...     ...               ...
# 481847  2019-12-31 20:30:00+00:00      UK            3018.0
# 481848  2019-12-31 21:00:00+00:00      UK            3018.0
# 481849  2019-12-31 21:30:00+00:00      UK            3015.0
# 481850  2019-12-31 22:00:00+00:00      UK            3012.0
# 481851  2019-12-31 22:30:00+00:00      UK            2830.0
#
#                                  Fossil Gas                     \
#        Actual Consumption Actual Aggregated Actual Consumption
# 0                     0.0            1029.0                0.0
# 1                     0.0            1019.0                0.0
# 2                     0.0            1015.0                0.0
# 3                     0.0            1014.0                0.0
# 4                     0.0             926.0                0.0
# ...                   ...               ...                ...
# 481847                NaN           12699.0                0.0
# 481848                NaN           11988.0                0.0
# 481849                NaN           10583.0                0.0
# 481850                NaN           10401.0                0.0
# 481851                NaN            9933.0                0.0
#
#         Fossil Hard coal                           Fossil Oil  \
#        Actual Aggregated Actual Consumption Actual Aggregated
# 0                   16.0                0.0               0.0
# 1                   16.0                0.0               0.0
# 2                   15.0                0.0               0.0
# 3                   15.0                0.0               0.0
# 4                   14.0                0.0               0.0
# ...                  ...                ...               ...
# 481847            1578.0                0.0               0.0
# 481848            1113.0                0.0               0.0
# 481849            1104.0                0.0               0.0
# 481850             999.0                0.0               0.0
# 481851             913.0                0.0               0.0
#
#                            ...      Wind Onshore                     \
#        Actual Consumption  ... Actual Aggregated Actual Consumption
# 0                     0.0  ...              63.0                0.0
# 1                     0.0  ...              61.0                0.0
# 2                     0.0  ...              65.0                0.0
# 3                     0.0  ...              71.0                0.0
# 4                     0.0  ...              74.0                0.0
# ...                   ...  ...               ...                ...
# 481847                0.0  ...            3351.0              193.0
# 481848                0.0  ...            3494.0              239.0
# 481849                0.0  ...            3718.0              280.0
# 481850                0.0  ...            3890.0              307.0
# 481851                0.0  ...            3677.0              302.0
#
#                  Nuclear Fossil Brown coal/Lignite                     \
#        Actual Aggregated         Actual Aggregated Actual Consumption
# 0                    NaN                       NaN                NaN
# 1                    NaN                       NaN                NaN
# 2                    NaN                       NaN                NaN
# 3                    NaN                       NaN                NaN
# 4                    NaN                       NaN                NaN
# ...                  ...                       ...                ...
# 481847            6961.0                       NaN                NaN
# 481848            6955.0                       NaN                NaN
# 481849            6969.0                       NaN                NaN
# 481850            6962.0                       NaN                NaN
# 481851            6958.0                       NaN                NaN
#
#        Fossil Coal-derived gas                               Nuclear  \
#              Actual Aggregated Actual Consumption Actual Consumption
# 0                          NaN                NaN                NaN
# 1                          NaN                NaN                NaN
# 2                          NaN                NaN                NaN
# 3                          NaN                NaN                NaN
# 4                          NaN                NaN                NaN
# ...                        ...                ...                ...
# 481847                     NaN                NaN                NaN
# 481848                     NaN                NaN                NaN
# 481849                     NaN                NaN                NaN
# 481850                     NaN                NaN                NaN
# 481851                     NaN                NaN                NaN
#
#            Wind Offshore
#        Actual Aggregated Actual Consumption
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2                    NaN                NaN
# 3                    NaN                NaN
# 4                    NaN                NaN
# ...                  ...                ...
# 481847            1964.0                NaN
# 481848            1770.0                NaN
# 481849            1816.0                NaN
# 481850            1985.0                NaN
# 481851            2178.0                NaN
#
# [481852 rows x 36 columns]

# %%
df1['index']= pd.to_datetime(df1['index'], utc = True)

# %%
df1['index'] = df1['index'].dt.tz_localize(None)

# %%
df1 = df1.groupby([df1['index'].map(lambda x: "{}/{}/{}".format(x.day, x.month, x.year)), df1['Country']])

# %%
df1 = df1.sum()
# Out:
# C:\Users\daabv\AppData\Local\Temp\ipykernel_9044\2422872323.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df1.sum()

# %%
df1.index.sort
# Out:
# <bound method Index.sort of MultiIndex([('1/1/2015', 'AT'),
#             ('1/1/2015', 'DE'),
#             ('1/1/2015', 'FR'),
#             ('1/1/2015', 'UK'),
#             ('1/1/2016', 'AT'),
#             ('1/1/2016', 'DE'),
#             ('1/1/2016', 'FR'),
#             ('1/1/2016', 'UK'),
#             ('1/1/2017', 'AT'),
#             ('1/1/2017', 'DE'),
#             ...
#             ('9/9/2017', 'FR'),
#             ('9/9/2017', 'UK'),
#             ('9/9/2018', 'AT'),
#             ('9/9/2018', 'DE'),
#             ('9/9/2018', 'FR'),
#             ('9/9/2018', 'UK'),
#             ('9/9/2019', 'AT'),
#             ('9/9/2019', 'DE'),
#             ('9/9/2019', 'FR'),
#             ('9/9/2019', 'UK')],
#            names=['index', 'Country'], length=7308)>

# %%
df1.to_excel("installed_capacity_per_production_type.xlsx")

# %% [markdown]
# # Actual generation per generation unit

# %%
df = pd.DataFrame()

start = pd.Timestamp('20190101', tz='Europe/Brussels')
end = pd.Timestamp('20200102', tz='Europe/Brussels')

country_code = ['FR']

for count, value in enumerate(country_code) :
    temp_df = client.query_generation_per_plant(value, start=start,end=end, psr_type=None)
    temp_df.insert(0, 'Country', value)
    df = pd.concat([df, temp_df])
    print(value)
    temp_df = pd.DataFrame()

# %% [markdown]
# # Installed capacity per production unit

# %%
df = pd.DataFrame()

country_code = ['RS', 'SK', 'SI', 'ES', 'SE', 'CH', 'GB']

# out : HR, CY, DK, DE, LU, MD'AL', 'AT', 'BE', 'BA', 'BG', 'CZ', 'DE_LU', 'DE_AT_LU',
               #'EE', 'FI', 'FR', 'GR', 'HU', 'IE', 'IT',
               #'LV', 'LT', 'ME', 'NL', 'MK', 'NO', 'PL',
               #'PT', 'RO', 

for count, value in enumerate(country_code) :
    temp_df = client.query_installed_generation_capacity_per_unit(value, start=start,end=end, psr_type=None)
    temp_df.insert(0, 'Country', value)
    df = pd.concat([df, temp_df])
    print(value)
    temp_df = pd.DataFrame()
# Out:
# RS
# SK
# SI
# ES
# SE
# CH
# GB
